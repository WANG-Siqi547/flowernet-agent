# %%
# 1. 安装核心依赖 (直接安装关键包，避免 requirements.txt 路径问题)
# !pip install fastapi==0.109.0 uvicorn==0.27.0 pydantic==2.5.3 pyngrok==7.0.5 nest-asyncio==1.5.8 requests==2.31.0
# !pip install torch transformers FlagEmbedding sentence-transformers scikit-learn rouge-score rank_bm25 nltk jieba numpy pandas

# 3. 下载 nltk 必要的资源数据
import nltk
nltk.download('punkt')
nltk.download('stopwords')

import nest_asyncio
from pyngrok import ngrok
from fastapi import FastAPI
from pydantic import BaseModel

# 应用 nest_asyncio 补丁
nest_asyncio.apply()

# 2. 配置 FastAPI
app = FastAPI()

class GenerateRequest(BaseModel):
    text: str
    task: str = "verify"

@app.get("/")
def home():
    return {"message": "FlowerNet Verifying Layer API is Online"}

@app.post("/verify")
async def verify(data: GenerateRequest):
    # TODO: 添加验证逻辑
    return {"status": "pending", "score": 0.0}

# 3. 启动 Ngrok 隧道 (可选，免费账户有端点限制)
try:
    NGROK_TOKEN = "38bwDJs8sMknK17RpFvQYzbje6A_4n2bZFtn2gao8U4qCf7gR"
    ngrok.set_auth_token(NGROK_TOKEN)
    public_url = ngrok.connect(8000)
    print(f"✅ API 公网地址: {public_url}")
except Exception as e:
    print(f"⚠️ Ngrok 失败（可能端点超限），使用本地地址")
    print(f"   本地地址: http://localhost:8000")
    print(f"   错误: {str(e)[:100]}")

# 4. 在后台运行 FastAPI
import uvicorn
import threading

def run_api():
    uvicorn.run(app, host="0.0.0.0", port=8000, log_level="info", use_colors=False)

api_thread = threading.Thread(target=run_api, daemon=True)
api_thread.start()
print("🚀 FastAPI 后台服务已启动")
# Out:
# ...
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# ...
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.5
#     Uninstalling requests-2.32.5:
#       Successfully uninstalled requests-2.32.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# inscriptis 2.7.0 requires requests<3.0.0,>=2.32.3, but you have requests 2.31.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.31.0 which is incompatible.
# google-adk 1.21.0 requires fastapi<0.124.0,>=0.115.0, but you have fastapi 0.109.0 which is incompatible.
# google-adk 1.21.0 requires requests<3.0.0,>=2.32.4, but you have requests 2.31.0 which is incompatible.
# ...
